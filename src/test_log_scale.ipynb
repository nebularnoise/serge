# %%
from final_model_log_scale import AudioDataset
import matplotlib.pyplot as plt
import numpy as np

# %%
motu = AudioDataset("../notebooks/motu/motu_dataset/*.wav", process=True, slice_size=128)
# Out:
# Preprocessing audio dataset...
# [=====================]
# Done!

# %%
S,f = motu[4]
S   = S.numpy()

plt.figure(figsize=(20,10))
plt.subplot(121)
plt.imshow(np.exp(S), cmap="jet", aspect="auto", origin="lower")
plt.colorbar()
plt.subplot(122)
plt.imshow(S, cmap="jet", aspect="auto", origin="lower")
plt.colorbar()
plt.show()
